# %%
#Импорт
import sys

# %%
import sys
from datetime import datetime

# Читаем все строки из stdin и убираем лишние пробелы
lines = sys.stdin.read().splitlines()

# Обрабатываем и выводим строки (каждую в обратном порядке)
dates = []
for line in lines:
    my_date = datetime.strptime(line,'%Y-%m-%d')
    dates.append(my_date)
print((max(dates) - min(dates)).days)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys

#Читаем все входные данные
moves = list(map(int, sys.stdin.read().splitlines()))

#Если данных нет – не выводим ничего
if not moves:
    sys.exit()

#Определяем, кто сделал последний ход
last_player = "Анри" if len(moves) % 2 == 1 else "Дима"
last_number = moves[-1]

#Проверяем чётность последнего хода и выводим победителя
if last_number % 2 == 0:
    print(last_player)
else:
    print("Анри" if last_player == "Дима" else "Дима")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys

#Читаем все входные данные
heights = list(map(int, sys.stdin.read().splitlines()))

# 🔹 Если данных нет – не выводим ничего
if len(heights) == 0:
    print('нет учеников')
else:
  mean = sum(heights) / len(heights)
  print(f'Рост самого низкого ученика: {min(heights)}')
  print(f'Рост самого высокого ученика: {max(heights)}')
  print(f'Средний рост: {mean}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys

#Читаем все входные данные
strings = list(map(str, sys.stdin.read().splitlines()))

comments = [i for i in strings if i.strip()[0] == '#']
print(len(comments))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys

#Читаем все входные данные
strings = list(map(str, sys.stdin.read().splitlines()))
strings_space = [i if len(i)>0 else "TECT" for i in strings]

code = [i for i in strings_space if not(i.strip()[0] == '#')]
print('\n'.join(code).replace('TECT',''))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys

#Читаем все входные данные
strings = list(map(str, sys.stdin.read().splitlines()))
tag = strings[-1]
strings.remove(tag)

polit_only = [i for i in strings if i.split(' / ')[1] == tag]
my_val = sorted(polit_only,key=lambda x: (float(x.split(' / ')[2]),x.split(' / ')[0]))
news = [i.split(' / ')[0] for i in my_val]
print('\n'.join(news))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys
from datetime import datetime

#Читаем все входные данные
strings = list(map(str, sys.stdin.read().splitlines()))
my_dates = [datetime.strptime(d,'%d.%m.%Y') for d in strings]
asc_sort = sorted(my_dates)
desc_sort = sorted(my_dates,reverse=True)

has_duplicates = len(my_dates) > len(set(my_dates))
if(has_duplicates):
  print('MIX')
else:
  if(my_dates == asc_sort):
    print('ASC')
  elif(my_dates == desc_sort):
    print('DESC')
  else:
    print('MIX')

# %% [markdown]
# ![image.png](attachment:image.png)
